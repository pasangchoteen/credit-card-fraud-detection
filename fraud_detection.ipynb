# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a Pandas DataFrame
data = pd.read_csv('creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Checking for nulls in each column
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Distribution of Legit transactions & Fraudulent transactions
#0 --> Normal Transaction
#1 --> fraudulent transaction

data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# Taking the mean of the data columns based on class
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# Separating the data for analysis
legit = data[data.Class == 0]
fraud = data[data.Class == 1]

print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
# statistical measures of the data
print("\tLegit Transactions data stat:\n")
print(legit.Amount.describe())

print("\n\tFraud Transactions data stat:\n")
print(fraud.Amount.describe())
# Out:
# 	Legit Transactions data stat:
#
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64
#
# 	Fraud Transactions data stat:
#
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
'''
This Dataset is highly unblanced
There is Under-Sampling of Fraud data.
Number of Fraudulent Transactions --> 492
Number of Legit Transactions --> 284315

So, now we will build a sample dataset containing similar distribution of Legit transactions and Fraudulent Transactions
'''
# Taking only the required no of legit sample data
legit_sample = legit.sample(n=492)

#Concatenating two DataFrames
new_dataset = pd.concat([legit_sample, fraud], axis=0)

new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 114911   73669.0 -1.694731  0.354838  0.149354 -0.198226 -2.627326  0.995440
# 277692  167800.0  0.149639  1.024500 -0.399566 -0.535690  0.871659 -0.856433
# 179219  123973.0 -0.544535  0.082062  0.315851 -1.542980  2.620919  3.884597
# 19364    30217.0  1.031784 -0.733888  0.031080 -1.824939 -0.897134 -1.191475
# 174520  121947.0  1.527838 -1.090245 -2.014584 -0.042078  0.399260  0.241904
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 114911  1.520382  0.769352 -0.421687  ...  0.255466  0.574613  0.432320
# 277692  0.956674 -0.096137 -0.005090  ... -0.344586 -0.854469  0.098553
# 179219 -0.461460  1.157314 -0.077374  ... -0.139096 -0.547390  0.042784
# 19364   0.126963 -0.245920  1.851156  ... -0.059102 -0.104113 -0.091606
# 174520  0.369336 -0.169296  0.672357  ...  0.495345  1.066920 -0.432251
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      96017.073171  0.030664  0.077565 -0.044097 -0.012260  0.064658
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.003004  0.114659  0.048146  0.055808  ... -0.002069 -0.011313
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.057742  0.003565  0.022995 -0.016877 -0.025767  0.000512  0.022402
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       83.556443
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#Now we are ready to build a credit card fraud detection model

#Splitting the data into Features & Targets
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

#Split the data into Training data & Testing Data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
#Model Training - We will be using Linear Regression in this model
model = LogisticRegression()

# Training the Model with Training Data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
#Model Evaluation - We will be using Accuracy Score  

# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)

# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy on Training data :  0.928843710292249
# Accuracy score on Test Data :  0.9187817258883249

# %%
# Given data
total_invited_hrd = 333
completion_rate = 0.45
energy_percentage = 0.14
asia_percentage = 0.2

# Calculate completed survey
completed_survey = total_invited_hrd * completion_rate

# Calculate completed survey in energy sector
completed_survey_energy = completed_survey * energy_percentage

# Calculate completed survey in Asia
completed_survey_asia = completed_survey * asia_percentage

# Calculate expected number of HRD in Asia based on head office location
expected_hrd_asia = total_invited_hrd * asia_percentage

# Calculate difference
difference = completed_survey_asia - expected_hrd_asia

print("Number of HRD who completed the survey in Asia:", completed_survey_asia)
print("Expected number of HRD in Asia based on head office location:", expected_hrd_asia)
print("Difference:", difference)
# Out:
# Number of HRD who completed the survey in Asia: 29.97
# Expected number of HRD in Asia based on head office location: 66.60000000000001
# Difference: -36.63000000000001
